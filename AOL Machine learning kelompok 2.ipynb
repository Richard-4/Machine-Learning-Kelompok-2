# %% [markdown]
# <div style="align-text:center">
#     <h1><b>Machine Learning Project</b></h1>
# </div>

# %% [markdown]
# <div>
# <h3><b>Frame the probem and look at the big picture</b></h3>
# <p>Tahap pertama yang dilakukan adalah menentukan permasalahan yang akan diselesaikan. Pada kelompok kami, permasalahan yang ingin kami selesaikan adalah masalah kekurangan gizi pada anak - anak.</p>
# </div>

# %% [markdown]
# <div>
# <h3><b>Get the data</b></h3>
# <p>Data yang kami dapatkan adalah data kekurangan gizi pada anak anak di Bandung. Data ini berisikan data anak - anak di bandung yang kekurangan gizi berdasarkan pertumbuhannya.</p>
# </div>

# %%
import pandas as pd
import requests

url = 'http://data.bandung.go.id/index.php/portal/api/0c9835d5-b55e-45fe-815b-be40a7dbc41f'
response_json = requests.get(url)
response = response_json.json()
dataframe = pd.DataFrame(response['data'])
dataframe.head()
# Out:
#   kode_kecamatan kecamatan    puskesmas  jumlah_balita_ditimbang  \
# 0       32.73.01  Sukasari     Sukarasa                      512
# 1       32.73.01  Sukasari       Ledeng                      805
# 2       32.73.01  Sukasari  Karangsetra                      635
# 3       32.73.01  Sukasari     Sarijadi                      779
# 4       32.73.07  Sukajadi     Sukajadi                     3038
#
#   jumlah_balita_gizi_lebih  persentase_jumlah_balita_gizi_lebih  \
# 0                        4                                 0.78
# 1                       25                                 3.11
# 2                       13                                 2.05
# 3                       55                                 7.06
# 4                      239                                 7.87
#
#    jumlah_balita_bb_normal  persentase_jumlah_balita_bb_normal  \
# 0                      453                               88.48
# ...

# %% [markdown]
# <div>
# <h3><b>Explore the data</b></h3>
# </div>

# %% [markdown]
# <div>
# <h3><b>Prepare the data</b></h3>
# <ol>
#     <b>
#     <li>Data discretation</li>
#     <li>Data cleaning</li>
#     <li>Data integration</li>
#     <li>Data transformation</li>
#     <li>Data reduction</li>
#     </b>
# </ol>
# </div>

# %% [markdown]
# <div>
# <h3><b>Explore the models and select the best one</b></h3>
# </div>

# %% [markdown]
# <div>
# <h3><b>Fine tune the models</b></h3>
# </div>

# %% [markdown]
# <div>
# <h3><b>Present the solution</b></h3>
# </div>
